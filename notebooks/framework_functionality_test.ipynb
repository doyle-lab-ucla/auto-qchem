# %% [markdown]
# ### Import classes from autoqchem

# %%
from autoqchem.molecule import molecule
from autoqchem.slurm_manager import slurm_manager

# %% [markdown]
# ### Set the level of logging.
# Autoqchem prints out log messages, while the logger has verbosity levels: "ERROR", "WARNING", "INFO", "DEBUG" with increasing amount of messages. If you are running for the first time "INFO" is good, once you are comfortable you can switch it to "WARNING" or "ERROR".

# %%
import logging
logging.basicConfig(level=logging.INFO)

# %% [markdown]
# We will use a single smiles string for this test

# %%
smiles_str = "C(C)(CP(c1ccccc1)c1ccccc1)(CP(c1ccccc1)c1ccccc1)[4CH2][1P]([2c]1ccccc1)[3c]1ccccc1"

# %% [markdown]
# ### Initialize the molecule from smiles

# %%
mol = molecule(smiles_str)
# Out:
# INFO:autoqchem.molecule:Initializing molecule with canonical smiles: CC([4CH2][1P]([3c]1ccccc1)[2c]1ccccc1)(CP(c1ccccc1)c1ccccc1)CP(c1ccccc1)c1ccccc1
# INFO:autoqchem.molecule:Creating initial geometry with option 'best'.
# INFO:autoqchem.molecule:Initial geometry created successfully.

# %% [markdown]
# ### Draw it!
# It should look decent, OpenBabel performs MMFF94 optimization with a conformer search. If it doesn't look good, there might be issues with openbabel installation (this is rare, but can happen).

# %%
mol.draw()
# Out:
# <div id="molecule_088f3fe5-c0fd-49b9-b126-6156892203d0"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: '/',
#                            paths: {imolecule: ['nbextensions/imolecule.min', 'https://rawgit.com/patrickfuller/imolecule/master/imolecule/js/build/imolecule.min']}});
#            require(['imolecule'], function () {
#                var $d = $('#molecule_088f3fe5-c0fd-49b9-b126-6156892203d0');
#                $d.width(400); $d.height(300);
#                $d.imolecule = jQuery.extend({}, imolecule);
#                $d.imolecule.create($d, {drawingType: 'ball and stick',
#                                         cameraType: 'perspective',
#                                         shader: 'lambert',
#                                         showSave: false});
#                $d.imolecule.addElements({});
#                $d.imolecule.draw({"atoms":[{"charge":-0.05855106815995701,"element":"C","location":[-1.8653601818095622,0.9947185085586945,0.7623758404270161]},{"charge":-0.018726013715944033,"element":"C","location":[-0.5106108310757631,0.31218133862189446,0.4585742059958158]},{"charge":-0.018287961247189257,"element":"C","location":[-0.7345676337336888,-1.1771364492176049,0.023960902987733124]},{"charge":0.032448507731739046,"element":"H","location":[-1.4746700813179334,-1.2001302043794335,-0.7799857751256613]},{"charge":0.032448507731739046,"element":"H","location":[0.2154536492368715,-1.5440875769571325,-0.3813076738706559]},{"charge":-0.0432918928786537,"element":"P","location":[-1.2264954547822664,-2.470496934428515,1.2541517194510237]},{"charge":-0.018940131992844743,"element":"C","location":[-2.9956642249825682,-2.120881294709606,1.5039805995145477]},{"charge":-0.05383764763895145,"element":"C","location":[-3.9932002535457025,-2.4137210006267864,0.5642532820055125]},{"charge":-0.061155322965266976,"element":"C","location":[-5.32706429247404,-2.067324176629948,0.8006143947769299]},{"charge":-0.061720393585195266,"element":"C","location":[-5.683358229831487,-1.4155013748921943,1.977626498643982]},{"charge":-0.061155322965266976,"element":"C","location":[-4.709772888481231,-1.127617683626003,2.9284145503807393]},{"charge":-0.05383764763895145,"element":"C","location":[-3.380259255538891,-1.4902335288714428,2.6986738190039685]},{"charge":-0.018940131992844743,"element":"C","location":[-1.2536813546328618,-4.016092214323514,0.2725870351212217]},{"charge":-0.05383764763895145,"element":"C","location":[-1.1715917066647075,-5.239463567388996,0.9595672887137883]},{"charge":-0.061155322965266976,"element":"C","location":[-1.186463443316363,-6.460965781312117,0.2742218319161559]},{"charge":-0.061720393585195266,"element":"C","location":[-1.2900634270910383,-6.47891776000737,-1.1155157114347913]},{"charge":-0.061155322965266976,"element":"C","location":[-1.368843574426539,-5.2781023094998964,-1.8143141399988023]},{"charge":-0.05383764763895145,"element":"C","location":[-1.3438284342405127,-4.061792232969321,-1.1259559004579311]},{"charge":-0.018287961247189257,"element":"C","location":[0.1930770319508217,1.0716057544349267,-0.7200257468006513]},{"charge":-0.0432918928786537,"element":"P","location":[-0.6715443000010781,1.135377752312068,-2.357431578280297]},{"charge":-0.018940131992844743,"element":"C","location":[0.32384167602661895,2.372602007786254,-3.248595676746232]},{"charge":-0.05383764763895145,"element":"C","location":[1.7087496581634345,2.277336068308011,-3.4353696173069266]},{"charge":-0.061155322965266976,"element":"C","location":[2.413382660144294,3.278983140181719,-4.109975646052175]},{"charge":-0.061720393585195266,"element":"C","location":[1.743980892023146,4.397125402213933,-4.599245041523671]},{"charge":-0.061155322965266976,"element":"C","location":[0.3695142145659087,4.513784826207166,-4.415661919259502]},{"charge":-0.05383764763895145,"element":"C","location":[-0.3342034260440139,3.508699729585433,-3.7468058519447136]},{"charge":-0.018940131992844743,"element":"C","location":[-0.2460269150570853,-0.41332125776765527,-3.215208120492358]},{"charge":-0.05383764763895145,"element":"C","location":[-1.2092378685930583,-0.9538451301752534,-4.084978244266638]},{"charge":-0.061155322965266976,"element":"C","location":[-0.9957520052204849,-2.1717507367538293,-4.737910664116363]},{"charge":-0.061720393585195266,"element":"C","location":[0.18841442446783718,-2.8723913583283114,-4.533915190950988]},{"charge":-0.061155322965266976,"element":"C","location":[1.1588838775644579,-2.351257566740038,-3.6840789447274536]},{"charge":-0.05383764763895145,"element":"C","location":[0.9442827898579602,-1.1305976836176157,-3.035050888853953]},{"charge":-0.018287961247189257,"element":"C","location":[0.42050750116026814,0.35187440571312756,1.7210269366126048]},{"charge":-0.0432918928786537,"element":"P","location":[0.6771775477852193,1.9 ...

# %% [markdown]
# ### Initialize the moleucle with conformer search
# molecule class constructor has an option of max_num_conformers, by default set to 1. The geometry optimization already searches over many conformations, but only one is returned. To return a set of diverse conformers use option ```max_num_conformers```

# %%
mol_conf = molecule(smiles_str, max_num_conformers=30)
# Out:
# INFO:autoqchem.molecule:Initializing molecule with canonical smiles: CC([4CH2][1P]([3c]1ccccc1)[2c]1ccccc1)(CP(c1ccccc1)c1ccccc1)CP(c1ccccc1)c1ccccc1
# INFO:autoqchem.molecule:Creating initial geometry with option 'best'.
# INFO:autoqchem.molecule:Initial geometry created successfully.
# INFO:autoqchem.molecule:Conformer Search generated 30 conformations of CC([4CH2][1P]([3c]1ccccc1)[2c]1ccccc1)(CP(c1ccccc1)c1ccccc1)CP(c1ccccc1)c1ccccc1 molecule

# %% [markdown]
# ### Draw some conformers

# %%
mol.draw(conformer_num=0)
mol.draw(conformer_num=13)
# Out:
# <div id="molecule_008b2839-fdee-4a5d-867b-ccee8b4610d0"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: '/',
#                            paths: {imolecule: ['nbextensions/imolecule.min', 'https://rawgit.com/patrickfuller/imolecule/master/imolecule/js/build/imolecule.min']}});
#            require(['imolecule'], function () {
#                var $d = $('#molecule_008b2839-fdee-4a5d-867b-ccee8b4610d0');
#                $d.width(400); $d.height(300);
#                $d.imolecule = jQuery.extend({}, imolecule);
#                $d.imolecule.create($d, {drawingType: 'ball and stick',
#                                         cameraType: 'perspective',
#                                         shader: 'lambert',
#                                         showSave: false});
#                $d.imolecule.addElements({});
#                $d.imolecule.draw({"atoms":[{"charge":-0.05855106815995701,"element":"C","location":[-1.8653601818095622,0.9947185085586945,0.7623758404270161]},{"charge":-0.018726013715944033,"element":"C","location":[-0.5106108310757631,0.31218133862189446,0.4585742059958158]},{"charge":-0.018287961247189257,"element":"C","location":[-0.7345676337336888,-1.1771364492176049,0.023960902987733124]},{"charge":0.032448507731739046,"element":"H","location":[-1.4746700813179334,-1.2001302043794335,-0.7799857751256613]},{"charge":0.032448507731739046,"element":"H","location":[0.2154536492368715,-1.5440875769571325,-0.3813076738706559]},{"charge":-0.0432918928786537,"element":"P","location":[-1.2264954547822664,-2.470496934428515,1.2541517194510237]},{"charge":-0.018940131992844743,"element":"C","location":[-2.9956642249825682,-2.120881294709606,1.5039805995145477]},{"charge":-0.05383764763895145,"element":"C","location":[-3.9932002535457025,-2.4137210006267864,0.5642532820055125]},{"charge":-0.061155322965266976,"element":"C","location":[-5.32706429247404,-2.067324176629948,0.8006143947769299]},{"charge":-0.061720393585195266,"element":"C","location":[-5.683358229831487,-1.4155013748921943,1.977626498643982]},{"charge":-0.061155322965266976,"element":"C","location":[-4.709772888481231,-1.127617683626003,2.9284145503807393]},{"charge":-0.05383764763895145,"element":"C","location":[-3.380259255538891,-1.4902335288714428,2.6986738190039685]},{"charge":-0.018940131992844743,"element":"C","location":[-1.2536813546328618,-4.016092214323514,0.2725870351212217]},{"charge":-0.05383764763895145,"element":"C","location":[-1.1715917066647075,-5.239463567388996,0.9595672887137883]},{"charge":-0.061155322965266976,"element":"C","location":[-1.186463443316363,-6.460965781312117,0.2742218319161559]},{"charge":-0.061720393585195266,"element":"C","location":[-1.2900634270910383,-6.47891776000737,-1.1155157114347913]},{"charge":-0.061155322965266976,"element":"C","location":[-1.368843574426539,-5.2781023094998964,-1.8143141399988023]},{"charge":-0.05383764763895145,"element":"C","location":[-1.3438284342405127,-4.061792232969321,-1.1259559004579311]},{"charge":-0.018287961247189257,"element":"C","location":[0.1930770319508217,1.0716057544349267,-0.7200257468006513]},{"charge":-0.0432918928786537,"element":"P","location":[-0.6715443000010781,1.135377752312068,-2.357431578280297]},{"charge":-0.018940131992844743,"element":"C","location":[0.32384167602661895,2.372602007786254,-3.248595676746232]},{"charge":-0.05383764763895145,"element":"C","location":[1.7087496581634345,2.277336068308011,-3.4353696173069266]},{"charge":-0.061155322965266976,"element":"C","location":[2.413382660144294,3.278983140181719,-4.109975646052175]},{"charge":-0.061720393585195266,"element":"C","location":[1.743980892023146,4.397125402213933,-4.599245041523671]},{"charge":-0.061155322965266976,"element":"C","location":[0.3695142145659087,4.513784826207166,-4.415661919259502]},{"charge":-0.05383764763895145,"element":"C","location":[-0.3342034260440139,3.508699729585433,-3.7468058519447136]},{"charge":-0.018940131992844743,"element":"C","location":[-0.2460269150570853,-0.41332125776765527,-3.215208120492358]},{"charge":-0.05383764763895145,"element":"C","location":[-1.2092378685930583,-0.9538451301752534,-4.084978244266638]},{"charge":-0.061155322965266976,"element":"C","location":[-0.9957520052204849,-2.1717507367538293,-4.737910664116363]},{"charge":-0.061720393585195266,"element":"C","location":[0.18841442446783718,-2.8723913583283114,-4.533915190950988]},{"charge":-0.061155322965266976,"element":"C","location":[1.1588838775644579,-2.351257566740038,-3.6840789447274536]},{"charge":-0.05383764763895145,"element":"C","location":[0.9442827898579602,-1.1305976836176157,-3.035050888853953]},{"charge":-0.018287961247189257,"element":"C","location":[0.42050750116026814,0.35187440571312756,1.7210269366126048]},{"charge":-0.0432918928786537,"element":"P","location":[0.6771775477852193,1.9 ...
# <div id="molecule_c8c1f584-7f2b-4983-81e7-7ef7de6e36e9"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: '/',
#                            paths: {imolecule: ['nbextensions/imolecule.min', 'https://rawgit.com/patrickfuller/imolecule/master/imolecule/js/build/imolecule.min']}});
#            require(['imolecule'], function () {
#                var $d = $('#molecule_c8c1f584-7f2b-4983-81e7-7ef7de6e36e9');
#                $d.width(400); $d.height(300);
#                $d.imolecule = jQuery.extend({}, imolecule);
#                $d.imolecule.create($d, {drawingType: 'ball and stick',
#                                         cameraType: 'perspective',
#                                         shader: 'lambert',
#                                         showSave: false});
#                $d.imolecule.addElements({});
#                $d.imolecule.draw({"atoms":[{"charge":-0.05855106815995701,"element":"C","location":[-1.8653601818095622,0.9947185085586945,0.7623758404270161]},{"charge":-0.018726013715944033,"element":"C","location":[-0.5106108310757631,0.31218133862189446,0.4585742059958158]},{"charge":-0.018287961247189257,"element":"C","location":[-0.7345676337336888,-1.1771364492176049,0.023960902987733124]},{"charge":0.032448507731739046,"element":"H","location":[-1.4746700813179334,-1.2001302043794335,-0.7799857751256613]},{"charge":0.032448507731739046,"element":"H","location":[0.2154536492368715,-1.5440875769571325,-0.3813076738706559]},{"charge":-0.0432918928786537,"element":"P","location":[-1.2264954547822664,-2.470496934428515,1.2541517194510237]},{"charge":-0.018940131992844743,"element":"C","location":[-2.9956642249825682,-2.120881294709606,1.5039805995145477]},{"charge":-0.05383764763895145,"element":"C","location":[-3.9932002535457025,-2.4137210006267864,0.5642532820055125]},{"charge":-0.061155322965266976,"element":"C","location":[-5.32706429247404,-2.067324176629948,0.8006143947769299]},{"charge":-0.061720393585195266,"element":"C","location":[-5.683358229831487,-1.4155013748921943,1.977626498643982]},{"charge":-0.061155322965266976,"element":"C","location":[-4.709772888481231,-1.127617683626003,2.9284145503807393]},{"charge":-0.05383764763895145,"element":"C","location":[-3.380259255538891,-1.4902335288714428,2.6986738190039685]},{"charge":-0.018940131992844743,"element":"C","location":[-1.2536813546328618,-4.016092214323514,0.2725870351212217]},{"charge":-0.05383764763895145,"element":"C","location":[-1.1715917066647075,-5.239463567388996,0.9595672887137883]},{"charge":-0.061155322965266976,"element":"C","location":[-1.186463443316363,-6.460965781312117,0.2742218319161559]},{"charge":-0.061720393585195266,"element":"C","location":[-1.2900634270910383,-6.47891776000737,-1.1155157114347913]},{"charge":-0.061155322965266976,"element":"C","location":[-1.368843574426539,-5.2781023094998964,-1.8143141399988023]},{"charge":-0.05383764763895145,"element":"C","location":[-1.3438284342405127,-4.061792232969321,-1.1259559004579311]},{"charge":-0.018287961247189257,"element":"C","location":[0.1930770319508217,1.0716057544349267,-0.7200257468006513]},{"charge":-0.0432918928786537,"element":"P","location":[-0.6715443000010781,1.135377752312068,-2.357431578280297]},{"charge":-0.018940131992844743,"element":"C","location":[0.32384167602661895,2.372602007786254,-3.248595676746232]},{"charge":-0.05383764763895145,"element":"C","location":[1.7087496581634345,2.277336068308011,-3.4353696173069266]},{"charge":-0.061155322965266976,"element":"C","location":[2.413382660144294,3.278983140181719,-4.109975646052175]},{"charge":-0.061720393585195266,"element":"C","location":[1.743980892023146,4.397125402213933,-4.599245041523671]},{"charge":-0.061155322965266976,"element":"C","location":[0.3695142145659087,4.513784826207166,-4.415661919259502]},{"charge":-0.05383764763895145,"element":"C","location":[-0.3342034260440139,3.508699729585433,-3.7468058519447136]},{"charge":-0.018940131992844743,"element":"C","location":[-0.2460269150570853,-0.41332125776765527,-3.215208120492358]},{"charge":-0.05383764763895145,"element":"C","location":[-1.2092378685930583,-0.9538451301752534,-4.084978244266638]},{"charge":-0.061155322965266976,"element":"C","location":[-0.9957520052204849,-2.1717507367538293,-4.737910664116363]},{"charge":-0.061720393585195266,"element":"C","location":[0.18841442446783718,-2.8723913583283114,-4.533915190950988]},{"charge":-0.061155322965266976,"element":"C","location":[1.1588838775644579,-2.351257566740038,-3.6840789447274536]},{"charge":-0.05383764763895145,"element":"C","location":[0.9442827898579602,-1.1305976836176157,-3.035050888853953]},{"charge":-0.018287961247189257,"element":"C","location":[0.42050750116026814,0.35187440571312756,1.7210269366126048]},{"charge":-0.0432918928786537,"element":"P","location":[0.6771775477852193,1.9 ...

# %% [markdown]
# ### Test whether you can access slurm
# If you have an account on della, feel free to change host to ```della.princeton.edu```. We will use ```adroit.princeton.edu```

# %% [markdown]
# ### Initialize the slurm manager
# change user parameter to your user

# %%
sm = slurm_manager(user='zuranski', host='adroit.princeton.edu')

# %% [markdown]
# ### Verify that you can create an ssh tunnel into
# Follow prompts for password and duo authentication. This tunnel will be used to manage jobs from within the notebook

# %%
sm.connect()

# %% [markdown]
# ### Check that you can see your jobs on the remote server
# If the following command returns a table with your jobs currently running on the server, it's a success. If you have no jobs running, only a header row will be displayed.

# %%
sm.squeue(summary=False)
# Out:
# Empty DataFrame
# Columns: [JOBID, PARTITION, NAME, USER, ST, TIME, NODES, NODELIST(REASON)]
# Index: []
