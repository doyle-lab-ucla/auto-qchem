# %% [markdown]
# ### Import classes from autoqchem

# %%
from autoqchem.molecule import molecule
from autoqchem.slurm_manager import slurm_manager

# %% [markdown]
# ### Set the level of logging
# Autoqchem prints out log messages, while the logger has various verbosity levels that you can set. If you are running for the first time "INFO" is good, once you are comfortable you can switch it to "WARNING" or "ERROR".

# %%
import logging
logging.basicConfig(level=logging.INFO)

# %% [markdown]
# We will use a single smiles string for this test

# %%
smiles_str = "C(C)(CP(c1ccccc1)c1ccccc1)(CP(c1ccccc1)c1ccccc1)[4CH2][1P]([2c]1ccccc1)[3c]1ccccc1"

# %% [markdown]
# ### Initialize the molecule from smiles

# %%
mol = molecule(smiles_str)
# Out:
# INFO:autoqchem.molecule:Initializing molecule with canonical smiles: CC([4CH2][1P]([3c]1ccccc1)[2c]1ccccc1)(CP(c1ccccc1)c1ccccc1)CP(c1ccccc1)c1ccccc1
# INFO:autoqchem.molecule:Creating initial geometry with option 'best'.
# INFO:autoqchem.molecule:Initial geometry created successfully.

# %% [markdown]
# ### Draw it!
# It should look decent, OpenBabel performs MMFF94 optimization with a conformer search. If it doesn't look good, there might be issues with openbabel installation (this is rare, but can happen).

# %%
mol.draw()
# Out:
# <div id="molecule_cc372191-96c7-4877-a910-6d5985dc8a0c"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: '/',
#                            paths: {imolecule: ['nbextensions/imolecule.min', 'https://rawgit.com/patrickfuller/imolecule/master/imolecule/js/build/imolecule.min']}});
#            require(['imolecule'], function () {
#                var $d = $('#molecule_cc372191-96c7-4877-a910-6d5985dc8a0c');
#                $d.width(400); $d.height(300);
#                $d.imolecule = jQuery.extend({}, imolecule);
#                $d.imolecule.create($d, {drawingType: 'ball and stick',
#                                         cameraType: 'perspective',
#                                         shader: 'lambert',
#                                         showSave: false});
#                $d.imolecule.addElements({});
#                $d.imolecule.draw({"atoms":[{"charge":-0.05855106815995701,"element":"C","location":[-1.9293514503605544,-0.40228525389719716,-0.8203682256486753]},{"charge":-0.018726013715944033,"element":"C","location":[-0.6082829595614836,0.1087891197033981,-0.19632052857375126]},{"charge":-0.018287961247189257,"element":"C","location":[-0.6694176490974906,1.6574715775305147,0.06543712496487795]},{"charge":0.032448507731739046,"element":"H","location":[-1.3344155810437168,1.8251665854913144,0.9163899638829299]},{"charge":0.032448507731739046,"element":"H","location":[0.31237785630385595,2.023577788526875,0.3859147825394936]},{"charge":-0.0432918928786537,"element":"P","location":[-1.3838138955016694,2.744711568821454,-1.2577433917064573]},{"charge":-0.018940131992844743,"element":"C","location":[-1.541908276474807,4.361144260893397,-0.41254348964791254]},{"charge":-0.05383764763895145,"element":"C","location":[-0.9661125519294815,5.545847992915207,-0.8983750043731136]},{"charge":-0.061155322965266976,"element":"C","location":[-1.1581151743562856,6.767431800850522,-0.24368101283133298]},{"charge":-0.061720393585195266,"element":"C","location":[-1.9471496652078983,6.833088935925664,0.8985049967081159]},{"charge":-0.061155322965266976,"element":"C","location":[-2.5469468637950854,5.677414055812022,1.3871042899973256]},{"charge":-0.05383764763895145,"element":"C","location":[-2.3493081733779433,4.455493732528254,0.7342077714063452]},{"charge":-0.018940131992844743,"element":"C","location":[-0.06829305486086312,3.0212880611521578,-2.4700929120242785]},{"charge":-0.05383764763895145,"element":"C","location":[-0.444398507053263,3.1460904972341486,-3.8188132783520494]},{"charge":-0.061155322965266976,"element":"C","location":[0.5012056043751554,3.4136900661742295,-4.811112302841716]},{"charge":-0.061720393585195266,"element":"C","location":[1.8427695863788305,3.5530673752907918,-4.471295859500612]},{"charge":-0.061155322965266976,"element":"C","location":[2.23582313577531,3.428159367900436,-3.1405041111394127]},{"charge":-0.05383764763895145,"element":"C","location":[1.286586722096323,3.1682663132638833,-2.1468256017574774]},{"charge":-0.018287961247189257,"element":"C","location":[-0.3160371251268206,-0.6476751807012056,1.1479522125455828]},{"charge":-0.0432918928786537,"element":"P","location":[-1.3091373339730699,-0.3074186027895536,2.6737183668594335]},{"charge":-0.018940131992844743,"element":"C","location":[-2.8993305691530704,-1.119508811849121,2.3068578741271084]},{"charge":-0.05383764763895145,"element":"C","location":[-3.0889379353672406,-2.50792968610625,2.312144322715185]},{"charge":-0.061155322965266976,"element":"C","location":[-4.323776813759473,-3.066021264172155,1.967221971654971]},{"charge":-0.061720393585195266,"element":"C","location":[-5.3859731095542465,-2.2440056467925324,1.6019885842164308]},{"charge":-0.061155322965266976,"element":"C","location":[-5.221583850974849,-0.8625168827216302,1.6036449029852327]},{"charge":-0.05383764763895145,"element":"C","location":[-3.993035789667469,-0.3055743702888525,1.968426632291401]},{"charge":-0.018940131992844743,"element":"C","location":[-0.589870508275431,-1.4229268692420503,3.9360122611580826]},{"charge":-0.05383764763895145,"element":"C","location":[-0.8756990327048118,-1.1650309878304705,5.286901328341377]},{"charge":-0.061155322965266976,"element":"C","location":[-0.38088713963959453,-1.9904559533778934,6.303048276742492]},{"charge":-0.061720393585195266,"element":"C","location":[0.40623035689850706,-3.0933981708605502,5.9871476279031155]},{"charge":-0.061155322965266976,"element":"C","location":[0.708531882474972,-3.362297765400621,4.6560432307902]},{"charge":-0.05383764763895145,"element":"C","location":[0.22176712952597155,-2.5292354978913076,3.6432142986612894]},{"charge":-0.018287961247189257,"element":"C","location":[0.5686388931437945,-0.18369198628360695,-1.1986440856471137]},{"charge":-0.0432918928786537,"element":"P","location":[0.9021092614483042,-1.952 ...

# %% [markdown]
# ### Initialize the moleucle with conformer search
# molecule class constructor has an option of max_num_conformers, by default set to 1. The geometry optimization already searches over many conformations, but only one is returned. To return a set of diverse conformers use option ```max_num_conformers```

# %%
mol_conf = molecule(smiles_str, max_num_conformers=30)
# Out:
# INFO:autoqchem.molecule:Initializing molecule with canonical smiles: CC([4CH2][1P]([3c]1ccccc1)[2c]1ccccc1)(CP(c1ccccc1)c1ccccc1)CP(c1ccccc1)c1ccccc1
# INFO:autoqchem.molecule:Creating initial geometry with option 'best'.
# INFO:autoqchem.molecule:Initial geometry created successfully.
# INFO:autoqchem.molecule:Conformer Search generated 30 conformations of CC([4CH2][1P]([3c]1ccccc1)[2c]1ccccc1)(CP(c1ccccc1)c1ccccc1)CP(c1ccccc1)c1ccccc1 molecule

# %% [markdown]
# ### Draw some conformers

# %%
mol.draw(conformer_num=0)
mol.draw(conformer_num=29)
# Out:
# <div id="molecule_7c5c7f1c-2222-4602-a9dd-19682bae4cb7"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: '/',
#                            paths: {imolecule: ['nbextensions/imolecule.min', 'https://rawgit.com/patrickfuller/imolecule/master/imolecule/js/build/imolecule.min']}});
#            require(['imolecule'], function () {
#                var $d = $('#molecule_7c5c7f1c-2222-4602-a9dd-19682bae4cb7');
#                $d.width(400); $d.height(300);
#                $d.imolecule = jQuery.extend({}, imolecule);
#                $d.imolecule.create($d, {drawingType: 'ball and stick',
#                                         cameraType: 'perspective',
#                                         shader: 'lambert',
#                                         showSave: false});
#                $d.imolecule.addElements({});
#                $d.imolecule.draw({"atoms":[{"charge":-0.05855106815995701,"element":"C","location":[-1.9293514503605544,-0.40228525389719716,-0.8203682256486753]},{"charge":-0.018726013715944033,"element":"C","location":[-0.6082829595614836,0.1087891197033981,-0.19632052857375126]},{"charge":-0.018287961247189257,"element":"C","location":[-0.6694176490974906,1.6574715775305147,0.06543712496487795]},{"charge":0.032448507731739046,"element":"H","location":[-1.3344155810437168,1.8251665854913144,0.9163899638829299]},{"charge":0.032448507731739046,"element":"H","location":[0.31237785630385595,2.023577788526875,0.3859147825394936]},{"charge":-0.0432918928786537,"element":"P","location":[-1.3838138955016694,2.744711568821454,-1.2577433917064573]},{"charge":-0.018940131992844743,"element":"C","location":[-1.541908276474807,4.361144260893397,-0.41254348964791254]},{"charge":-0.05383764763895145,"element":"C","location":[-0.9661125519294815,5.545847992915207,-0.8983750043731136]},{"charge":-0.061155322965266976,"element":"C","location":[-1.1581151743562856,6.767431800850522,-0.24368101283133298]},{"charge":-0.061720393585195266,"element":"C","location":[-1.9471496652078983,6.833088935925664,0.8985049967081159]},{"charge":-0.061155322965266976,"element":"C","location":[-2.5469468637950854,5.677414055812022,1.3871042899973256]},{"charge":-0.05383764763895145,"element":"C","location":[-2.3493081733779433,4.455493732528254,0.7342077714063452]},{"charge":-0.018940131992844743,"element":"C","location":[-0.06829305486086312,3.0212880611521578,-2.4700929120242785]},{"charge":-0.05383764763895145,"element":"C","location":[-0.444398507053263,3.1460904972341486,-3.8188132783520494]},{"charge":-0.061155322965266976,"element":"C","location":[0.5012056043751554,3.4136900661742295,-4.811112302841716]},{"charge":-0.061720393585195266,"element":"C","location":[1.8427695863788305,3.5530673752907918,-4.471295859500612]},{"charge":-0.061155322965266976,"element":"C","location":[2.23582313577531,3.428159367900436,-3.1405041111394127]},{"charge":-0.05383764763895145,"element":"C","location":[1.286586722096323,3.1682663132638833,-2.1468256017574774]},{"charge":-0.018287961247189257,"element":"C","location":[-0.3160371251268206,-0.6476751807012056,1.1479522125455828]},{"charge":-0.0432918928786537,"element":"P","location":[-1.3091373339730699,-0.3074186027895536,2.6737183668594335]},{"charge":-0.018940131992844743,"element":"C","location":[-2.8993305691530704,-1.119508811849121,2.3068578741271084]},{"charge":-0.05383764763895145,"element":"C","location":[-3.0889379353672406,-2.50792968610625,2.312144322715185]},{"charge":-0.061155322965266976,"element":"C","location":[-4.323776813759473,-3.066021264172155,1.967221971654971]},{"charge":-0.061720393585195266,"element":"C","location":[-5.3859731095542465,-2.2440056467925324,1.6019885842164308]},{"charge":-0.061155322965266976,"element":"C","location":[-5.221583850974849,-0.8625168827216302,1.6036449029852327]},{"charge":-0.05383764763895145,"element":"C","location":[-3.993035789667469,-0.3055743702888525,1.968426632291401]},{"charge":-0.018940131992844743,"element":"C","location":[-0.589870508275431,-1.4229268692420503,3.9360122611580826]},{"charge":-0.05383764763895145,"element":"C","location":[-0.8756990327048118,-1.1650309878304705,5.286901328341377]},{"charge":-0.061155322965266976,"element":"C","location":[-0.38088713963959453,-1.9904559533778934,6.303048276742492]},{"charge":-0.061720393585195266,"element":"C","location":[0.40623035689850706,-3.0933981708605502,5.9871476279031155]},{"charge":-0.061155322965266976,"element":"C","location":[0.708531882474972,-3.362297765400621,4.6560432307902]},{"charge":-0.05383764763895145,"element":"C","location":[0.22176712952597155,-2.5292354978913076,3.6432142986612894]},{"charge":-0.018287961247189257,"element":"C","location":[0.5686388931437945,-0.18369198628360695,-1.1986440856471137]},{"charge":-0.0432918928786537,"element":"P","location":[0.9021092614483042,-1.952 ...
# <div id="molecule_ecc85059-aad8-4d64-8edb-111a8c07bd04"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: '/',
#                            paths: {imolecule: ['nbextensions/imolecule.min', 'https://rawgit.com/patrickfuller/imolecule/master/imolecule/js/build/imolecule.min']}});
#            require(['imolecule'], function () {
#                var $d = $('#molecule_ecc85059-aad8-4d64-8edb-111a8c07bd04');
#                $d.width(400); $d.height(300);
#                $d.imolecule = jQuery.extend({}, imolecule);
#                $d.imolecule.create($d, {drawingType: 'ball and stick',
#                                         cameraType: 'perspective',
#                                         shader: 'lambert',
#                                         showSave: false});
#                $d.imolecule.addElements({});
#                $d.imolecule.draw({"atoms":[{"charge":-0.05855106815995701,"element":"C","location":[-1.9293514503605544,-0.40228525389719716,-0.8203682256486753]},{"charge":-0.018726013715944033,"element":"C","location":[-0.6082829595614836,0.1087891197033981,-0.19632052857375126]},{"charge":-0.018287961247189257,"element":"C","location":[-0.6694176490974906,1.6574715775305147,0.06543712496487795]},{"charge":0.032448507731739046,"element":"H","location":[-1.3344155810437168,1.8251665854913144,0.9163899638829299]},{"charge":0.032448507731739046,"element":"H","location":[0.31237785630385595,2.023577788526875,0.3859147825394936]},{"charge":-0.0432918928786537,"element":"P","location":[-1.3838138955016694,2.744711568821454,-1.2577433917064573]},{"charge":-0.018940131992844743,"element":"C","location":[-1.541908276474807,4.361144260893397,-0.41254348964791254]},{"charge":-0.05383764763895145,"element":"C","location":[-0.9661125519294815,5.545847992915207,-0.8983750043731136]},{"charge":-0.061155322965266976,"element":"C","location":[-1.1581151743562856,6.767431800850522,-0.24368101283133298]},{"charge":-0.061720393585195266,"element":"C","location":[-1.9471496652078983,6.833088935925664,0.8985049967081159]},{"charge":-0.061155322965266976,"element":"C","location":[-2.5469468637950854,5.677414055812022,1.3871042899973256]},{"charge":-0.05383764763895145,"element":"C","location":[-2.3493081733779433,4.455493732528254,0.7342077714063452]},{"charge":-0.018940131992844743,"element":"C","location":[-0.06829305486086312,3.0212880611521578,-2.4700929120242785]},{"charge":-0.05383764763895145,"element":"C","location":[-0.444398507053263,3.1460904972341486,-3.8188132783520494]},{"charge":-0.061155322965266976,"element":"C","location":[0.5012056043751554,3.4136900661742295,-4.811112302841716]},{"charge":-0.061720393585195266,"element":"C","location":[1.8427695863788305,3.5530673752907918,-4.471295859500612]},{"charge":-0.061155322965266976,"element":"C","location":[2.23582313577531,3.428159367900436,-3.1405041111394127]},{"charge":-0.05383764763895145,"element":"C","location":[1.286586722096323,3.1682663132638833,-2.1468256017574774]},{"charge":-0.018287961247189257,"element":"C","location":[-0.3160371251268206,-0.6476751807012056,1.1479522125455828]},{"charge":-0.0432918928786537,"element":"P","location":[-1.3091373339730699,-0.3074186027895536,2.6737183668594335]},{"charge":-0.018940131992844743,"element":"C","location":[-2.8993305691530704,-1.119508811849121,2.3068578741271084]},{"charge":-0.05383764763895145,"element":"C","location":[-3.0889379353672406,-2.50792968610625,2.312144322715185]},{"charge":-0.061155322965266976,"element":"C","location":[-4.323776813759473,-3.066021264172155,1.967221971654971]},{"charge":-0.061720393585195266,"element":"C","location":[-5.3859731095542465,-2.2440056467925324,1.6019885842164308]},{"charge":-0.061155322965266976,"element":"C","location":[-5.221583850974849,-0.8625168827216302,1.6036449029852327]},{"charge":-0.05383764763895145,"element":"C","location":[-3.993035789667469,-0.3055743702888525,1.968426632291401]},{"charge":-0.018940131992844743,"element":"C","location":[-0.589870508275431,-1.4229268692420503,3.9360122611580826]},{"charge":-0.05383764763895145,"element":"C","location":[-0.8756990327048118,-1.1650309878304705,5.286901328341377]},{"charge":-0.061155322965266976,"element":"C","location":[-0.38088713963959453,-1.9904559533778934,6.303048276742492]},{"charge":-0.061720393585195266,"element":"C","location":[0.40623035689850706,-3.0933981708605502,5.9871476279031155]},{"charge":-0.061155322965266976,"element":"C","location":[0.708531882474972,-3.362297765400621,4.6560432307902]},{"charge":-0.05383764763895145,"element":"C","location":[0.22176712952597155,-2.5292354978913076,3.6432142986612894]},{"charge":-0.018287961247189257,"element":"C","location":[0.5686388931437945,-0.18369198628360695,-1.1986440856471137]},{"charge":-0.0432918928786537,"element":"P","location":[0.9021092614483042,-1.952 ...

# %% [markdown]
# ### Test whether you can access slurm
# If you have an account on della, feel free to change host to ```della.princeton.edu```. We will use ```adroit.princeton.edu```

# %% [markdown]
# ### Initialize the slurm manager
# change user parameter to your user

# %%
sm = slurm_manager(user='zuranski', host='adroit.princeton.edu')

# %% [markdown]
# ### Verify that you can create an ssh tunnel into the remote server
# Follow prompts for password and duo authentication. This tunnel will be used to manage jobs from within the notebook

# %%
sm.connect()
# Out:
# INFO:autoqchem.slurm_manager:Creating connection to adroit.princeton.edu as zuranski
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_7.4)
# Password: ········
#
#
# Duo two-factor login for zuranski
#
# Enter a passcode or select one of the following options:
#
#  1. Duo Push to XXX-XXX-5447
#  2. Phone call to XXX-XXX-5447
#  3. SMS passcodes to XXX-XXX-5447
#
# Passcode or option (1-3): 1
# INFO:paramiko.transport:Authentication (keyboard-interactive) successful!
# INFO:autoqchem.slurm_manager:Connected to adroit.princeton.edu as zuranski.

# %% [markdown]
# ### Check that you can see your jobs on the remote server
# If the following command returns a table with your jobs currently running on the server, it's a success. If you have no jobs running, only a header row will be displayed.

# %%
sm.squeue(summary=False)
# Out:
# Empty DataFrame
# Columns: [JOBID, PARTITION, NAME, USER, ST, TIME, NODES, NODELIST(REASON)]
# Index: []
